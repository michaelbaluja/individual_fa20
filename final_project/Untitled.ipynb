# %%
import pandas as pd
import geopandas as gpd

# %%
df_yelp = pd.read_csv("../data/yelp_SD_parks.csv")
df_yelp
# Out:
#                                       name  \
# 0                              Balboa Park
# 1                              Civita Park
# 2                          Waterfront Park
# 3                        Trolley Barn Park
# 4                            Bay View Park
# ..                                     ...
# 828                  Del Cerro - San Diego
# 829  San Diego Metropolitan Transit System
# 830                             Petco Park
# 831     Ann D. L'Heureux Memorial Dog Park
# 832                         Fairbrook Farm
#
#                                             address         phone  \
# 0                 1549 El Prado San Diego, CA 92101  1.619239e+10
# 1              7960 Civita Blvd San Diego, CA 92108           NaN
# 2              1600 Pacific Hwy San Diego, CA 92101  1.619233e+10
# 3      Adams Ave And Florida St San Diego, CA 92116           NaN
# 4                     413 1st St Coronado, CA 92118           NaN
# ...

# %%
df_y
# Out:
#       Unnamed: 0  address_number_primary address_dir_primary  \
# 0              0                    5600                 NaN
# 1              1                    2100                 NaN
# 2              2                    2100                 NaN
# 3              3                    1100                 NaN
# 4              4                     300                 NaN
# ...          ...                     ...                 ...
# 7601        7601                    2100                 NaN
# 7602        7602                    3200                 NaN
# 7603        7603                       0                 NaN
# 7604        7604                    8900                 NaN
# 7605        7605                    5100                 NaN
#
#      address_road_primary address_sfx_primary  \
# 0          MISSION CENTER                  RD
# 1                    PARK                 BLV
# 2                       K                  ST
# ...

# %%
a = pd.concat([df_yelp, df_y])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
a
# Out:
#       Unnamed: 0  Unnamed: 0.1                                       address  \
# 0              1           1.0       5000 UNIVERSITY AVE, San Diego, CA, USA
# 1              2           2.0          800 SAWTELLE AVE, San Diego, CA, USA
# 2              3           3.0       5000 UNIVERSITY AVE, San Diego, CA, USA
# 3              4           4.0  5200 CLAIREMONT MESA BLV, San Diego, CA, USA
# 4              6           6.0         4300 MANZANITA DR, San Diego, CA, USA
# ...          ...           ...                                           ...
# 7601        7601           NaN         2100 VALENTINO ST, San Diego, CA, USA
# 7602        7602           NaN          3200 TENNYSON ST, San Diego, CA, USA
# 7603        7603           NaN          0 EL CAMINO REAL, San Diego, CA, USA
# 7604        7604           NaN           8900 GENESEE AV, San Diego, CA, USA
# 7605        7605           NaN             5100 EWING ST, San Diego, CA, USA
#
# ...
