# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview

# %% [markdown]
# San Diego Parks and Rec has left me with the task to take a closer look at crime statistics and propose a solution that could help in the fight against gang related crimes and gang recruitment in the county of San Diego.
#
# In this Data science analysis report I will be exploring 2019 and 2020 San Diego crime statistics and be begging the question,"Has the amount of gang related crime between the summer vacation hours of 7pm and 11pm remained the same or increased?". Since gang related crime has increased, it is part of my task to report these findings to the county of San Diego and encourage park funding to these at risk neighborhoods. Funding would be used to implement an anti gang recruitment and awareness program to those parks and an adjustment to park and rec hours of operation to increase the activity at these parks which helps deter gang activity in parks.

# %% [markdown]
# # Name & GitHub
#
# - Name: Edmundo Zamora
# - GitHub Username: EdmundoZamora

# %% [markdown]
# # Research Question

# %% [markdown]
# Is there a relation between gang related crime and the summer month hours between 7pm and 11pm. How can we effectively find the at risk neighborhoods that are in need of anti gang community park programs such as L.A county's "summer night lights program" to both raise their safety and decrease gang violence within the next five years. The best place to implement a program against gang recuitment involves the active schedules of parks and the time the crime took place. Thus I Hypothesis that there will be a relation between beat/neighborhood and the time of gang related crime in the summer months.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Below is background knowledge and sources to prior work on why I would propose funding to for anti gang recuitment/awareness programs as well as what can be considered a gang related crime.
#
# https://theconversation.com/can-parks-help-cities-fight-crime-118322 This reference covers the background of crimes in parks which can be decreased by funding parks for beautification and mainting service to the parks facilites and amenities. It compares parks in all income neighborhoods, for higher income neighborhoods crime rates were already rare to none since funding and investing in their parks was readily available encouraging more patrons to enjoy the park. As for lower income neighborhoods in order to drop crime rates there had to be more community investment to build a sense of legitimate user owner ship. For low income neighborhoods surveillence of the park came with the growth of numbers of legitimate park users who came for the community activities set up by the community programs which are city funded.
#
# https://www.nrpa.org/parks-recreation-magazine/2016/march/using-design-to-reduce-crime/ This reference explains background of key points to upholding low crime rates in public parks by design. included in the key points is territorial reinforcemnt of legitimate park users which brings in more legitimate park users and improves park surveillance. Servicing and maintenance of the park facilities and greenery not only prevents the parks quality to deteriorate but prevents a drop in territorial reinforcement. To keep the park "clean and green" as the author Michael Cannavino mentions requires that the park is maintained as soon as possible to keep the positive patrons from seeing things such as "graffitti" or "damaged property" which would influence them to either not return as often or visit a non local park. The biggest take from this publication was the importance of building legitimate patrons of the public space and their retention
#
# https://cityparksalliance.org/resource/summer-night-lights-los-angeles/ This casestudy reference covers the background to the strategic approach which began in los angeles, to keep parks more active during the late after noon into the night, by keeping the park lights on and offering community activities deters gang violence by getting in the way of allowing gangmembers to commit a violent incident without little to no witnesses. The growth in funding to these parks in low income neighborhoods lead to an decrease of violence in these parks. The majority of these low income neighborhoods were of ethnicities known to join gangs, this program focused on offering positive activities for these at risk youth as a method for gang reduction. Not only does this promote more positive outlets for at risk youth but creates a sense of legitimate ownership of the parks they frequent improving on both positive patron retention and patron surveillence but also are likely to recipricate this ideology of positive park engagement to the youth when they are grown.
#
# https://www.nationalgangcenter.gov/survey-analysis/gang-related-offenses
# https://www.lapdonline.org/get_informed/content_basic_view/23469
# https://www.fbi.gov/investigate/violent-crime/gangs#:~:text=Many%20are%20sophisticated%20and%20well,after%20being%20sent%20to%20jail.
# What is typically considered gang related crimes? The three sources above boil down what typically can be considered gang related violence based off investigations and criminal records. It ranges from drug sales and running prostitution rings to the most common crime which is gun violence, drive bys, targeted person shootings at parks. also prelevent are burglaries, larceny and auto theft.
#
#
# https://cityparksalliance.org/resource/summer-night-lights-los-angeles/
# L.A county's "summer night lights program" which focuses on keeping the community parks active by offering community activities such as crafts and sports targets the fact that parks at dark are a hot spot for gang related meetings and crimes. The program supports the thought that an active park with actual park patreons disencourages non actual park patreons from lurking among the park and possibly committing a crime. The program operates between 7pm and 11pm in the summer. Its effectiveness has caused the program to also extend into the fall season.
#
#
# Education date ranges for data cleaning purposes:
#
# For San Diego 2018-2019
# Last day of instruction was june June 11 2019
# Source https://patch.com/california/san-diego/san-diego-school-calendar-2018-19-first-day-school-vacations
#
# First day of instruction was August 26 2019
# Source https://patch.com/california/lajolla/san-diego-unified-school-district-calendar-2019-2020
#
# For San Diego 2020-2021
# Last day of instruction was June 9 2020
# https://patch.com/california/lajolla/san-diego-unified-school-district-calendar-2019-2020
#
# First day of instruction was August 31 2020
# https://publicholidays.us/school-holidays/california/san-diego-unified-school-district/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# In the summer months when students are on break they are most vulnerable to gang recruitment and the neigborhood is vulnerable to gang related violence in the later hours of 7pm to 11pm, which are the times when park recreation centers typically are closed. which leads me to conclude:
#
# Null hypothesis
# Gang related crime remains consistent from summer 2019 to summer 2020 between the hours of 7pm and 11pm.
#
# Alternate hypothesis
# Gang related crime has increased from summer 2019 to summer 2020 between the hours of 7pm and 11pm.
#
# I believe that when there is more funding to parks with elevated levels of gang violence, such as providing serviced amenities for more activities in these low income neighborhoods it encourages more people such as families to frequent these parks and stay for longer hours into the afternoon which discourages gangs from frequenting these parks and potentially causing less violence among other territorial gangs.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: pd_calls_for_service_2019_datasd.csv
# - Link to the dataset: https://data.sandiego.gov/datasets/police-calls-for-service/
# - Number of observations: There are 590967 rows and 14 columns in this dataset
# - This data set will be used for its time column its neighborhood/beat column and crime committed column
#
# - Dataset Name: pd_calls_for_service_2020_datasd.csv
# - Link to the dataset: https://data.sandiego.gov/datasets/police-calls-for-service/
# - Number of observations: There are 522569 rows and 14 columns in this dataset
# - This data set will be used for its time column its neighborhood/beat column and crime committed column just like the 2019 dataset
#
# - Dataset Name: pd_calls_for_service_dictionary_datasd.csv
# - Link to the dataset: https://data.sandiego.gov/datasets/police-calls-for-service/
# - Number of observations: There are 289 rows and 2 columns in this dataset.
# - This dataset will be used to identify the gang related crimes and map those names onto the call_types which are in the 2019 and 2020 data set call_type column. For the sate of desrcriptive statistics.
#
# - Dataset Name: pd_beat_neighborhoods_datasd.csv
# - Link to the dataset: http://seshhat.datasd.org/pd/pd_beat_neighborhoods_datasd.csv
# - Number of observations: There are 125 rows and 2 columns in this dataset.
# - This dataset will be used to map the corresponding neighborhood/beat names to the beat codes in the 2019 and 2020 data. For the sate of desrcriptive statistics.

# %% [markdown]
# # Setup

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %%
call_type = pd.read_csv('pd_cfs_calltypes_datasd.csv',usecols = ['call_type','description'])
call_type
# Out:
#     call_type                description
# 0        1016        PRISONER IN CUSTODY
# 1      1016PT   PTU (PRISONER TRANSPORT)
# 2      1016QC      SHOPLIFTER/QUICK CITE
# 3        1021         PHONE YOUR STATION
# 4       1021H            PHONE YOUR HOME
# ..        ...                        ...
# 284       TLO  TERRORISM LIAISON OFFICER
# 285        TP            TRAFFIC PURSUIT
# 286       TRO      TRO VIOLATION, REPORT
# 287     VARDA                VARDA ALARM
# 288   WARRANT                    WARRANT
#
# [289 rows x 2 columns]

# %%
beat = pd.read_csv('pd_beat_neighborhoods_datasd.csv')
beat
# Out:
#      Beat          Neighborhood
# 0     111  Clairemont Mesa East
# 1     112  Clairemont Mesa West
# 2     113                Bay Ho
# 3     114      North Clairemont
# 4     115       University City
# ..    ...                   ...
# 120   933       Del Mar Heights
# 121   934         Carmel Valley
# 122   935            North City
# 123   936      Torrey Highlands
# 124   937  Black Mountain Ranch
#
# [125 rows x 2 columns]

# %%
# read in the first set
nine = pd.read_csv('pd_calls_for_service_2019_datasd.csv')
nine
# Out:
#         incident_num            date_time  day_of_week  \
# 0       E19010000001  2019-01-01 00:00:01            1
# 1       E19010000002  2019-01-01 00:00:04            1
# 2       E19010000003  2019-01-01 00:00:09            1
# 3       E19010000004  2019-01-01 00:00:19            1
# 4       E19010000005  2019-01-01 00:00:31            1
# ...              ...                  ...          ...
# 590962  E19120050370  2019-12-31 23:57:36            3
# 590963  E19120050372  2019-12-31 23:58:11            3
# 590964  E19120050373  2019-12-31 23:59:30            3
# 590965  E19120050374  2019-12-31 23:59:35            3
# 590966  E19120050375  2019-12-31 23:59:53            3
#
#         address_number_primary address_dir_primary address_road_primary  \
# 0                         3800                 NaN             NATIONAL
# 1                         6500                 NaN           REFLECTION
# 2                            0                 NaN                 06TH
# ...

# %%
# read in the second set
twent = pd.read_csv('pd_calls_for_service_2020_datasd.csv')
twent
# Out:
#         incident_num            date_time  day_of_week  \
# 0       E20010000001  2020-01-01 00:00:09            4
# 1       E20010000002  2020-01-01 00:00:20            4
# 2       E20010000003  2020-01-01 00:00:21            4
# 3       E20010000004  2020-01-01 00:00:32            4
# 4       E20010000005  2020-01-01 00:00:42            4
# ...              ...                  ...          ...
# 522564  E20120001602  2020-12-01 23:23:01            3
# 522565  E20120001605  2020-12-01 23:28:18            3
# 522566  E20120001608  2020-12-01 23:33:18            3
# 522567  E20120001616  2020-12-01 23:48:27            3
# 522568  E20120001618  2020-12-01 23:51:07            3
#
#         address_number_primary address_dir_primary address_road_primary  \
# 0                          400                 NaN                 06TH
# 1                         5000                 NaN           UNIVERSITY
# 2                          800                 NaN             SAWTELLE
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# - Here I cleaned out the call types im not interested in exploring in
# - Drop null value rows
# - Cleaned out beats that were not legitamite
# - Mapped the correct name for the beats/neighborhoods
# - Sectioned the data to the summer months and between 7-11pm
# - Made a column for the hour of the crime incident

# %%
Gang_related = ['11-6','11-6SPT','246','246R','247',
                '247R','415W','417','417R','10851',
                '10851R','221','211-SUSP','211R',
                '215','215R','459','459-SUSP',
                '459R','487','487R','488',
                '488R','647B','647F']

Gang_Call = call_type[call_type['call_type'].apply(lambda x: str(x) in Gang_related)]
Gang_Call
# Out:
#     call_type                                  description
# 5       10851                                   AUTO THEFT
# 7      10851R                             CAR THEFT REPORT
# 14       11-6                         DISCHARGING FIREARMS
# 15    11-6SPT  DISCHARGING FIREARM SHOT SPOTTER ACTIVATION
# 69   211-SUSP                        211 SUSPECT THERE NOW
# 72       211R                               ROBBERY REPORT
# 74        215                                  CAR JACKING
# 75       215R                            CARJACKING REPORT
# 88        246                     FIRING AT OCCP'D HSE/VEH
# 89       246R                FIRING AT OCCP'D HSE/VEH 1110
# 90        247                     FIRING AT UNOCCUPIED VEH
# 91       247R               FIRING AT UNOCCPD VEH/HSE 1110
# 114      415W               DISTURBING PEACE UNCONC WEAPON
# 115       417                         THREATENING W/WEAPON
# 116      417R                  THREATENING W/WEAPON REPORT
# ...

# %%
CALL = dict(zip(Gang_Call.call_type.values,Gang_Call.description.values))
CALL
# Out:
# {'10851': 'AUTO THEFT',
#  '10851R': 'CAR THEFT REPORT',
#  '11-6': 'DISCHARGING FIREARMS',
#  '11-6SPT': 'DISCHARGING FIREARM SHOT SPOTTER ACTIVATION',
#  '211-SUSP': '211 SUSPECT THERE NOW',
#  '211R': 'ROBBERY REPORT',
#  '215': 'CAR JACKING',
#  '215R': 'CARJACKING REPORT',
#  '246': "FIRING AT OCCP'D HSE/VEH",
#  '246R': "FIRING AT OCCP'D HSE/VEH 1110",
#  '247': 'FIRING AT UNOCCUPIED VEH',
#  '247R': 'FIRING AT UNOCCPD VEH/HSE 1110',
#  '415W': 'DISTURBING PEACE UNCONC WEAPON',
#  '417': 'THREATENING W/WEAPON',
#  '417R': 'THREATENING W/WEAPON REPORT',
#  '459': 'BURGLARY IN PROGRESS',
#  '459-SUSP': '459 SUSPECT THERE NOW',
#  '459R': 'BURGLARY REPORT',
#  '487': 'GRAND THEFT $950+',
#  '487R': 'GRAND THEFT/REPORT $950+',
#  '488': 'PETTY THEFT/UNDER $950',
#  '488R': 'PETTY THEFT REPORT/UNDER $950',
#  '647B': 'PROSTITUTION',
#  '647F': 'DRUNK - DRUGS/ALCOHOL'}

# %% [markdown]
# Here we have the call types we are interested in which are gang related according to my background and prior work sources.
# This is important as we can narrow down which beats/neighborhoods have more counts of gang related violence

# %% [markdown]
# Here I cleaned out the variables im not interested in exploring in
# Notice how one of the beats are a non three digit number.

# %%
# read in the first set
nine = pd.read_csv('pd_calls_for_service_2019_datasd.csv',usecols = ['date_time','day_of_week','call_type','beat','priority'])
nine.tail()
# Out:
#                   date_time  day_of_week call_type  beat  priority
# 590962  2019-12-31 23:57:36            3      FOOT   122         3
# 590963  2019-12-31 23:58:11            3      415N   311         3
# 590964  2019-12-31 23:59:30            3      1016    -1         2
# 590965  2019-12-31 23:59:35            3      1016   523         2
# 590966  2019-12-31 23:59:53            3       AU1   324         1

# %%
# check for nan values 
nine = nine.copy(deep = True)
rows_to_drop = nine[nine.isnull().any(axis=1)]
rows_to_drop.head()
# Out:
#                 date_time  day_of_week call_type  beat  priority
# 1710  2019-01-02 08:43:07            2       NaN   824         2
# 1736  2019-01-02 08:59:37            2       NaN   623         3
# 1795  2019-01-02 09:30:22            2       NaN   242         3
# 1815  2019-01-02 09:42:53            2       NaN   314         2
# 1852  2019-01-02 10:08:28            2       NaN   621         4

# %%
# dropping rows with nan values
nine = nine.dropna(how='any', subset=['date_time','day_of_week','call_type','beat','priority'])
nine.head()
# Out:
#              date_time  day_of_week call_type  beat  priority
# 0  2019-01-01 00:00:01            1       AU1   441         1
# 1  2019-01-01 00:00:04            1       415   321         2
# 2  2019-01-01 00:00:09            1        FD   523         2
# 3  2019-01-01 00:00:19            1       AU1   511         1
# 4  2019-01-01 00:00:31            1       586   523         4

# %% [markdown]
# - I also cleaned out beats that were not legitamite

# %%
nine = nine[nine['beat'].apply(lambda x: len(str(x)) == 3)]

valid_beats = [111, 112, 113, 114, 115, 116, 121, 122, 123, 124, 126, 231, 232,
       233, 234, 235, 241, 242, 243, 245, 246, 311, 312, 313, 314, 315,
       316, 321, 322, 323, 324, 325, 326, 327, 431, 432, 433, 434, 435,
       436, 437, 438, 439, 441, 442, 443, 444, 445, 446, 447, 451, 452,
       511, 512, 514, 515, 516, 517, 518, 521, 522, 523, 524, 525, 526,
       527, 528, 529, 531, 541, 611, 612, 613, 614, 615, 616, 617, 618,
       621, 622, 623, 624, 625, 626, 627, 628, 711, 712, 713, 714, 721,
       722, 723, 724, 725, 811, 812, 813, 814, 821, 822, 823, 824, 825,
       826, 827, 828, 829, 831, 832, 833, 834, 835, 836, 837, 838, 839,
       841, 931, 932, 933, 934, 935, 936, 937] 

nine = nine[nine['beat'].apply(lambda x: int(x) in valid_beats)]
nine.head()
# Out:
#              date_time  day_of_week call_type  beat  priority
# 0  2019-01-01 00:00:01            1       AU1   441         1
# 1  2019-01-01 00:00:04            1       415   321         2
# 2  2019-01-01 00:00:09            1        FD   523         2
# 3  2019-01-01 00:00:19            1       AU1   511         1
# 4  2019-01-01 00:00:31            1       586   523         4

# %% [markdown]
# - Here I filter out the call_types with the gang related call_types

# %%
# gang related crimes
nine = nine[nine['call_type'].apply(lambda x: str(x) in Gang_related)]
nine.head()
# Out:
#               date_time  day_of_week call_type  beat  priority
# 27  2019-01-01 00:07:10            1       246   452         1
# 32  2019-01-01 00:08:36            1       246   833         1
# 61  2019-01-01 00:23:23            1      11-6   512         0
# 63  2019-01-01 00:25:57            1      11-6   441         1
# 78  2019-01-01 00:34:07            1      647F   523         2

# %% [markdown]
# - I also mapped the correct name for the beats/neighborhoods

# %%
BEAT = dict(zip(beat.Beat.values,beat.Neighborhood.values))
BEAT
# Out:
# {111: 'Clairemont Mesa East',
#  112: 'Clairemont Mesa West',
#  113: 'Bay Ho',
#  114: 'North Clairemont',
#  115: 'University City',
#  116: 'Bay Park',
#  121: 'Mission Beach',
#  122: 'Pacific Beach',
#  123: 'Mission Bay Park',
#  124: 'La Jolla',
#  126: 'Torrey Pines',
#  231: 'Sabre Springs',
#  232: 'Carmel Mountain',
#  233: 'Rancho Penasquitos',
#  234: 'Rancho Bernardo',
#  235: 'San Pasqual',
#  241: 'Scripps Ranch',
#  242: 'Mira Mesa',
#  243: 'Miramar',
#  245: 'Rancho Encantada',
#  246: 'Miramar Ranch North',
#  311: 'Serra Mesa',
#  312: 'Tierrasanta',
#  313: 'Kearny Mesa',
#  314: 'Birdland',
#  315: 'Mission Valley East',
#  316: 'Qualcomm',
#  321: 'Grantville',
#  322: 'Allied Gardens',
#  323: 'Del Cerro',
#  324: 'Lake Murray',
#  325: 'San Carlos',
#  326: 'College West',
#  327: 'College East',
#  431: 'Emerald Hills',
#  432: 'Valencia Park',
#  433: 'Encanto',
#  434: 'Jamacha/Lomita',
#  435: 'Broadway Heights',
#  436: 'Skyline',
# ...

# %%
# map the correct beat/neighborhood name with its beat number
nine = nine.copy(deep = True)
beat = nine.beat.replace(BEAT)
nine.beat = beat
nine.head()
# Out:
#               date_time  day_of_week call_type               beat  priority
# 27  2019-01-01 00:07:10            1       246          O'Farrell         1
# 32  2019-01-01 00:08:36            1       246  Fairmount Village         1
# 61  2019-01-01 00:23:23            1      11-6      Logan Heights         0
# 63  2019-01-01 00:25:57            1      11-6      Mountain View         1
# 78  2019-01-01 00:34:07            1      647F            Gaslamp         2

# %% [markdown]
# #### I also mapped the correct description for the gang related Call_types

# %%
# map the correct call_type name with its description
nine = nine.copy(deep = True)
call_type = nine.call_type.replace(CALL)
nine.call_type = call_type

nine.head()
# Out:
#               date_time  day_of_week                 call_type  \
# 27  2019-01-01 00:07:10            1  FIRING AT OCCP'D HSE/VEH
# 32  2019-01-01 00:08:36            1  FIRING AT OCCP'D HSE/VEH
# 61  2019-01-01 00:23:23            1      DISCHARGING FIREARMS
# 63  2019-01-01 00:25:57            1      DISCHARGING FIREARMS
# 78  2019-01-01 00:34:07            1     DRUNK - DRUGS/ALCOHOL
#
#                  beat  priority
# 27          O'Farrell         1
# 32  Fairmount Village         1
# 61      Logan Heights         0
# 63      Mountain View         1
# 78            Gaslamp         2

# %% [markdown]
# #### Summer break is set between June 11 and August 26 in 2019 for San Diego Unified School District

# %%
nine = nine.copy(deep = True)
nine['date_time'] = pd.to_datetime(nine['date_time'])
nine = nine[nine['date_time'].between('2019-6-11', '2019-8-27')]
nine = nine.reset_index(drop = True)
nine.head()
# Out:
#             date_time  day_of_week               call_type  \
# 0 2019-06-11 00:24:10            1    DISCHARGING FIREARMS
# 1 2019-06-11 00:27:35            1        CAR THEFT REPORT
# 2 2019-06-11 01:22:53            1   DRUNK - DRUGS/ALCOHOL
# 3 2019-06-11 02:40:43            1    THREATENING W/WEAPON
# 4 2019-06-11 03:02:41            1  PETTY THEFT/UNDER $950
#
#                  beat  priority
# 0          Alta Vista         1
# 1  Rancho Penasquitos         2
# 2        Little Italy         2
# 3          North Park         0
# 4       Pacific Beach         2

# %% [markdown]
# #### The Summer Night Lights program is targeted between 7 pm and 11 pm

# %%
nine = nine.copy(deep = True)

nine = nine[nine['date_time'].map(lambda x: x.hour) > 18] # 7pm

nine = nine[nine['date_time'].map(lambda x: x.hour) < 24] # 11pm

# %% [markdown]
# #### We want a column of hour for each crime for each city in its own column, this variable is essential to see if there is a relation between times in hour a Gang related crime is committed in a beat/neighborhood.

# %%
nine = nine.copy(deep = True)
nine['time'] = nine['date_time'].map(lambda x: x.time())

nine['hour'] = nine.time.map(lambda x: x.hour)

nine = nine.reset_index(drop = True)
nine.head()
# Out:
#             date_time  day_of_week                 call_type  \
# 0 2019-06-11 19:08:59            1  GRAND THEFT/REPORT $950+
# 1 2019-06-11 19:22:48            1     DRUNK - DRUGS/ALCOHOL
# 2 2019-06-11 19:28:42            1    PETTY THEFT/UNDER $950
# 3 2019-06-11 19:31:27            1     DRUNK - DRUGS/ALCOHOL
# 4 2019-06-11 19:43:51            1      BURGLARY IN PROGRESS
#
#                 beat  priority      time  hour
# 0       Lincoln Park         9  19:08:59    19
# 1    Midway District         2  19:22:48    19
# 2    Egger Highlands         2  19:28:42    19
# 3             Nestor         2  19:31:27    19
# 4  Fairmount Village         0  19:43:51    19

# %% [markdown]
# #### I repeat the cleaning process on the 2020 crime statistics data below

# %%
# read in the first set
twent = pd.read_csv('pd_calls_for_service_2020_datasd.csv',usecols = ['date_time','day_of_week','address_road_primary','call_type','beat','priority'])

# dropping rows with nan values
twent = twent.dropna(how='any', subset=['date_time','day_of_week','call_type','beat','priority'])

# clean out non beats
twent = twent[twent['beat'].apply(lambda x: len(str(x)) == 3)]
twent = twent[twent['beat'].apply(lambda x: int(x) in valid_beats)]

# gun and weapon related
twent = twent[twent['call_type'].apply(lambda x: str(x) in Gang_related)]

# map the correct beat/neighborhood name with its beat number

twent = twent.copy(deep = True)
beat = twent.beat.replace(BEAT)
twent.beat = beat

# map the correct call_type name with its description
twent = twent.copy(deep = True)
call_type = twent.call_type.replace(CALL)
twent.call_type = call_type

twent['date_time'] = pd.to_datetime(twent['date_time'])

twent = twent[twent['date_time'].between('2020-6-9', '2020-8-31')] 
twent.reset_index(drop = True)

twent = twent[twent['date_time'].map(lambda x: x.hour) > 18] # 7pm -

twent = twent[twent['date_time'].map(lambda x: x.hour) < 24] # - 11pm

twent = twent.copy(deep = True)
twent['time'] = twent['date_time'].map(lambda x: x.time())

twent['hour'] = twent.time.map(lambda x: x.hour)

twent = twent.reset_index(drop = True)
twent.head()
# Out:
#             date_time  day_of_week address_road_primary  \
# 0 2020-06-09 19:53:39            3                 09TH
# 1 2020-06-09 20:48:22            3                 39TH
# 2 2020-06-09 20:53:22            3               COWLEY
# 3 2020-06-09 20:54:26            3                FROST
# 4 2020-06-09 21:13:39            3              POTOMAC
#
#                         call_type            beat  priority      time  hour
# 0                CAR THEFT REPORT   Core-Columbia         2  19:53:39    19
# 1                 BURGLARY REPORT  Fairmount Park         3  20:48:22    20
# 2            BURGLARY IN PROGRESS        Bay Park         0  20:53:22    20
# 3  DISTURBING PEACE UNCONC WEAPON        Birdland         0  20:54:26    20
# 4            DISCHARGING FIREARMS  Paradise Hills         1  21:13:39    21

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# Here are some descriptive Statistics for the gang related crimes of 2019

# %%
nine['call_type'].value_counts().plot.barh(figsize=(15,15)).invert_yaxis()


plt.title('Counts of Gang Related Crimes 7-11pm summer 2019', size = 20, loc = 'left')
plt.xlabel('Gang related crime count',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Gang related crimes',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = nine['call_type'].value_counts().values
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 18)

# %%
nine['hour'].value_counts().sort_index().plot.barh(figsize=(7,5))

plt.title('Counts of Gang Related Crimes 7-11pm summer 2019', size = 20, loc = 'left')
plt.xlabel('Gang related crimes ',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Hour count in 24hr',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = nine['hour'].value_counts().sort_index().values
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 15)

# %%
beats = nine['beat'].value_counts()
graph = beats.plot.barh(figsize=(20,40)).invert_yaxis()

plt.title('Counts of Gang Related Crimes per beat 7-11pm summer 2019', size = 20, loc = 'left')
plt.xlabel('Gang related crimes count',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Beat',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = beats.values
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 15)

# %%
top_ten = beats[:10]
graph = top_ten.plot.barh(figsize=(10,10)).invert_yaxis()

plt.title('Counts of Gang Related Crimes per Beat 7-11pm summer 2019', size = 20, loc = 'left')
plt.xlabel('Gang related crimes count',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Beat',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = top_ten.values
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 15)

# %%
# read in the first set
beat19 = pd.read_csv('pd_calls_for_service_2019_datasd.csv',usecols = ['date_time','day_of_week','address_road_primary','call_type','beat','priority'])

# dropping rows with nan values
beat19 = beat19.dropna(how='any', subset=['date_time','day_of_week','call_type','beat','priority'])

# clean out non beats
beat19 = beat19[beat19['beat'].apply(lambda x: len(str(x)) == 3)]
beat19 = beat19[beat19['beat'].apply(lambda x: int(x) in valid_beats)]

# gun and weapon related
beat19 = beat19[beat19['call_type'].apply(lambda x: str(x) in Gang_related)]

# map the correct beat/neighborhood name with its beat number

#twent = twent.copy(deep = True)
#beat = twent.beat.replace(BEAT)
#twent.beat = beat

beat19['date_time'] = pd.to_datetime(beat19['date_time'])

beat19 = beat19[beat19['date_time'].between('2019-6-11', '2019-8-27')] 
beat19.reset_index(drop = True)

beat19 = beat19[beat19['date_time'].map(lambda x: x.hour) > 18] # 7pm -

beat19 = beat19[beat19['date_time'].map(lambda x: x.hour) < 24] # - 11pm

beat19 = beat19.copy(deep = True)
beat19['time'] = beat19['date_time'].map(lambda x: x.time())

beat19['hour'] = beat19.time.map(lambda x: x.hour)

beat19 = beat19.reset_index(drop = True)
beat19.head()
# Out:
#             date_time  day_of_week address_road_primary call_type  beat  \
# 0 2019-06-11 19:08:59            1               EUCLID      487R   446
# 1 2019-06-11 19:22:48            1         SPORTS ARENA      647F   611
# 2 2019-06-11 19:28:42            1               SATURN       488   721
# 3 2019-06-11 19:31:27            1   AVENIDA DEL MEXICO      647F   722
# 4 2019-06-11 19:43:51            1             CHAMOUNE       459   833
#
#    priority      time  hour
# 0         9  19:08:59    19
# 1         2  19:22:48    19
# 2         2  19:28:42    19
# 3         2  19:31:27    19
# 4         0  19:43:51    19

# %%
outcome_1, predictors_1 = patsy.dmatrices('beat ~ hour', beat19) #make beat numeric?
mod_1 = sm.OLS(outcome_1, predictors_1)
res_1 = mod_1.fit()
print(res_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   beat   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.649
# Date:                Wed, 16 Dec 2020   Prob (F-statistic):              0.199
# Time:                        23:04:39   Log-Likelihood:                -11733.
# No. Observations:                1705   AIC:                         2.347e+04
# Df Residuals:                    1703   BIC:                         2.348e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    390.3462     86.713      4.502      0.000     220.272     560.421
# ...

# %%
sns.scatterplot(x='hour', y='beat', data=beat19)
xs = np.arange(beat19['hour'].min(), beat19['hour'].max())
ys = 5.3297 * xs + 390.3462
plt.plot(xs, ys, '--k', linewidth=4, label='Model')


plt.xlabel('Hour')
plt.ylabel('Beat Number')
plt.title('Relationship between hour and beat number 2019')
plt.legend();

# %% [markdown]
# #### There is a positive relation between the hour and the beat number here, very small however.

# %% [markdown]
# ### Here are the descriptive Statistics for the 2020 summer break

# %%
twent['call_type'].value_counts().plot.barh(figsize=(15,15), color = 'purple').invert_yaxis()


plt.title('Counts of Gang Related Crimes 7-11pm summer 2020', size = 20, loc = 'left')
plt.xlabel('Gang related crime count',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Gang related crimes',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = twent['call_type'].value_counts().values
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 18)

# %% [markdown]
# #### There has been an increase in the discharging of fire arms, from 359 to 583

# %%
twent['hour'].value_counts().sort_index().plot.barh(figsize=(7,5), color = 'purple')

plt.title('Counts of Gang Related Crimes 7-11pm summer 2020', size = 20, loc = 'left')
plt.xlabel('Gang related crimes ',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Hour count in 24hr',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = twent['hour'].value_counts().sort_index().values
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 15)

# %% [markdown]
# #### There also has been an increase of crimes corresponding to the hour it occured

# %%
beats_twent = twent['beat'].value_counts()
graph = beats_twent.plot.barh(figsize=(20,40),color = 'purple').invert_yaxis()

plt.title('Counts of Gang Related Crimes per Beat 7-11pm summer 2020', size = 20, loc = 'left')
plt.xlabel('Gang related crimes count',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Beat',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = beats_twent.values
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 15)

# %% [markdown]
# ### Zoning in on the top ten beats

# %%
beats_twent = twent['beat'].value_counts()[:10]
graph = beats_twent.plot.barh(figsize=(10,10),color = 'purple').invert_yaxis()

plt.title('Counts of Gang Related Crimes Top Ten Beats 7-11pm summer 2020', size = 20, loc = 'left')
plt.xlabel('Gang related crimes count',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Beat',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = beats_twent
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 15)

# %%
top_ten = beats[:10]
graph = top_ten.plot.barh(figsize=(10,10)).invert_yaxis()

plt.title('Counts of Gang Related Crimes per Beat 7-11pm summer 2019', size = 20, loc = 'left')
plt.xlabel('Gang related crimes count',size = 20)
plt.tick_params(axis='y', labelsize = 20 )
plt.ylabel('Beat',size = 20)
plt.tick_params(axis='x', labelsize = 20)

y = top_ten.values
for index, value in enumerate(y):
    plt.text(value, index, str(value),size = 15)

# %% [markdown]
# ### There has been a drop in rankings but this does not indicate that there is a drop in crime within the 7-11pm time frames between summers. Pacific Beach remained top one and North Park dropped in rank by one, on the other hand East Village rose up the rank as the second in rank  from 45 crimes to 65.

# %%
# read in the first set
twent_nu = pd.read_csv('pd_calls_for_service_2020_datasd.csv',usecols = ['date_time','day_of_week','address_road_primary','call_type','beat','priority'])

# dropping rows with nan values
twent_nu = twent_nu.dropna(how='any', subset=['date_time','day_of_week','call_type','beat','priority'])

# clean out non beats
twent_nu = twent_nu[twent_nu['beat'].apply(lambda x: len(str(x)) == 3)]
twent_nu = twent_nu[twent_nu['beat'].apply(lambda x: int(x) in valid_beats)]

# gun and weapon related
twent_nu = twent_nu[twent_nu['call_type'].apply(lambda x: str(x) in Gang_related)]

# map the correct beat/neighborhood name with its beat number

#twent = twent.copy(deep = True)
#beat = twent.beat.replace(BEAT)
#twent.beat = beat

twent_nu['date_time'] = pd.to_datetime(twent_nu['date_time'])

twent_nu = twent_nu[twent_nu['date_time'].between('2020-6-9', '2020-8-31')] 
twent_nu.reset_index(drop = True)

twent_nu = twent_nu[twent_nu['date_time'].map(lambda x: x.hour) > 18] # 7pm -

twent_nu = twent_nu[twent_nu['date_time'].map(lambda x: x.hour) < 24] # - 11pm

twent_nu = twent_nu.copy(deep = True)
twent_nu['time'] = twent_nu['date_time'].map(lambda x: x.time())

twent_nu['hour'] = twent_nu.time.map(lambda x: x.hour)

twent_nu = twent_nu.reset_index(drop = True)
twent_nu.head()
# Out:
#             date_time  day_of_week address_road_primary call_type  beat  \
# 0 2020-06-09 19:53:39            3                 09TH    10851R   524
# 1 2020-06-09 20:48:22            3                 39TH      459R   837
# 2 2020-06-09 20:53:22            3               COWLEY       459   116
# 3 2020-06-09 20:54:26            3                FROST      415W   314
# 4 2020-06-09 21:13:39            3              POTOMAC      11-6   438
#
#    priority      time  hour
# 0         2  19:53:39    19
# 1         3  20:48:22    20
# 2         0  20:53:22    20
# 3         0  20:54:26    20
# 4         1  21:13:39    21

# %%
outcome_1, predictors_1 = patsy.dmatrices('beat ~ hour', twent_nu)
mod_1 = sm.OLS(outcome_1, predictors_1)
res_1 = mod_1.fit()
print(res_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   beat   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.959
# Date:                Wed, 16 Dec 2020   Prob (F-statistic):              0.162
# Time:                        23:05:58   Log-Likelihood:                -13522.
# No. Observations:                1973   AIC:                         2.705e+04
# Df Residuals:                    1971   BIC:                         2.706e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    400.6898     80.679      4.966      0.000     242.464     558.916
# ...

# %%
sns.scatterplot(x='hour', y='beat', data=twent_nu)
xs = np.arange(twent['hour'].min(), twent['hour'].max())
ys = 5.3886 * xs + 400.6898
plt.plot(xs, ys, '--k', linewidth=4, label='Model')

plt.xlabel('Hour')
plt.ylabel('Beat Number')
plt.title('Relationship between hour and beat number 2020')
plt.legend();

# %% [markdown]
# #### There is also a positive relation between the hour and the beat number here, very small however again

# %%
nineteen = beat19.hour.value_counts().sort_index()
twenty = twent_nu.hour.value_counts().sort_index()
nineteen,twenty
# Out:
# (19    381
#  20    357
#  21    371
#  22    332
#  23    264
#  Name: hour, dtype: int64,
#  19    378
#  20    428
#  21    464
#  22    396
#  23    307
#  Name: hour, dtype: int64)

# %%
nineteen = beat19.hour.value_counts().sort_index().values
twenty = twent_nu.hour.value_counts().sort_index().values
nineteen,twenty
# Out:
# (array([381, 357, 371, 332, 264]), array([378, 428, 464, 396, 307]))

# %%
nineteen = beat19.hour.value_counts().sort_index().values
twenty = twent_nu.hour.value_counts().sort_index().values
labels = np.arange(19,24)

plt.bar(labels, nineteen, align='edge', width=-0.4)
plt.bar(labels, twenty, align='edge', width=0.4)
plt.legend(['Nineteen','Twenty'])
plt.xlabel('Hour count in 24hr',size = 20)
plt.ylabel('Gang related crimes count',size = 15)

plt.show()

# %% [markdown]
# ### Distribution shows the increase in gang related crimes from 2019 and 2020 summer break between the hours of 7-11pm

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Gathering the data for the county's reported gang violence for the past two years can be collected through the county's police department's crime database under public availability. No ones idenity would be in risk of a privacy violation since most of the data pertains to addresses, call_types, time of incident, and neighborhoods/beats. The only variable taken into consideration in the analysis where beat and time.
#
# The analysis was done in a single county in southern california, there arises an ethical concern which is that these result could be used to stereotype all county's of southern california. Biases I encountered is that neighborhoods some neighborhoods are bigger than others thus the population would be larger and naturally have a higher probability for crime to occur, such as the metropolitan areas of downtown and the neighborhoods near there which are more populated by minorities such as latino and blacks which are more prevalent in forming gangs which live among these parks in these low income neighborhoods. To counter act this I did not focus on a single beat/neighborhood but included them all in the analysis.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# Based on the exploritory data analysis, I can conclude that there was an increase in gang related crimes from the summer break hours of 7pm to 11pm between the years 2019 and 2020. Thus as part of my task and civil duty, I would strongly encourage the county of San Diego to implement an anti gang recruitment and awareness program to those parks and an adjustment to park and rec hours of operation to increase the activity at these parks which helps deter gang activity in parks.
#
# My hypothesis that Gang related crime remains consistent from summer 2019 to summer 2020 between the hours of 7pm and 11pm is wrong. which leads us to be in favor of the alternative hypothesis which is that it increases.
#
# A limitation in analysis was that post cleaning I turned nominal values into categorical values this hinders the relation ship between the beats/neighborhoods and the times a gang related crime would likely to occur.
#
# A technical limitation was that I was undergoing an issue with installing geopandas, if in the future another data scientist were to carry on this work and analysis, I would suggest zoning in on the parks and not just the beats and neighborhoods as this will give a more realistic analysis of gang related activity in parks which is the main concern with SD Parks and Rec.
